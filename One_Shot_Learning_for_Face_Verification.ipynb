# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwiks9635/New_Project_Ideas/blob/main/One_Shot_Learning_for_Face_Verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
! unzip /content/https:/www.kaggle.com/datasets/jayitabhattacharyya/face-match/face-match.zip

# %%
! unzip /content/https:/www.kaggle.com/datasets/sarthak1799/haarcascade/haarcascade.zip
# Out:
# Archive:  /content/https:/www.kaggle.com/datasets/sarthak1799/haarcascade/haarcascade.zip
#   inflating: haarcascade_eye.xml
#   inflating: haarcascade_frontalface_default.xml
#   inflating: haarcascade_smile.xml

# %%
import tensorflow as tf
import numpy as np
import os
from keras.layers import Conv2D, Activation, AveragePooling2D, MaxPooling2D, ZeroPadding2D, Input, concatenate
from keras.layers import Lambda, Dense, Flatten
from numpy import genfromtxt
import cv2
from keras.layers import BatchNormalization
from keras import backend as K
from keras.layers import *
from keras.models import Model
from sklearn.preprocessing import normalize
K.set_image_data_format('channels_first')
import random
import matplotlib.pyplot as plt
import keras
from keras.utils import plot_model
import sys

# %%
path = "/content/trainset"
face_path = "/content/haarcascade_frontalface_default.xml"

# %%
os.listdir(path)

# %%
reference_img =[]
selfie_img = []
n_sub=0

# %%
for folders in os.listdir(path):
  subfolder= os.path.join(path, folders)
  for sub in os.listdir(subfolder):
    n_sub = n_sub + 1
    img_dir = os.path.join(subfolder, sub)
    for img in os.listdir(img_dir):
      print(len(img))
      if 'script' in img:
        reference_img.append(img)
      else:
        selfie_img.append(img)

# %%
len(reference_img)
# Out:
# 1221

# %%
len(selfie_img)
# Out:
# 3198

# %%
image = cv2.imread("/content/trainset/0007/0007_0000643/0000000.jpg")
plt.imshow(image)
plt.show()

# %%
image_s = cv2.imread("/content/trainset/0007/0007_0000643/0007_0000643_script.jpg")
plt.imshow(image_s)
plt.show()

# %%
def inception_block_1a(X):
    X_3=Conv2D(96,(1,1),data_format='channels_first',name='inception_3a_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3a_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(128,(3,3),data_format='channels_first',name='inception_3a_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3a_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)

    X_5=Conv2D(16,(1,1),data_format='channels_first',name='inception_3a_5x5_conv1')(X)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3a_5x5_bn1')(X_5)
    X_5=Activation('relu')(X_5)
    X_5=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_5)
    X_5=Conv2D(32,(5,5),data_format='channels_first',name='inception_3a_5x5_conv2')(X_5)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3a_5x5_bn2')(X_5)
    X_5=Activation('relu')(X_5)

    X_pool = MaxPooling2D(pool_size=3, strides=2, data_format='channels_first')(X)
    X_pool = Conv2D(32, (1, 1), data_format='channels_first', name='inception_3a_pool_conv')(X_pool)
    X_pool = BatchNormalization(axis=1, epsilon=0.00001, name='inception_3a_pool_bn')(X_pool)
    X_pool = Activation('relu')(X_pool)
    X_pool = ZeroPadding2D(padding=((3, 4), (3, 4)), data_format='channels_first')(X_pool)

    X_1=Conv2D(64,(1,1),data_format='channels_first',name='inception_3a_1x1_conv')(X)
    X_1=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3a_1x1_bn')(X_1)
    X_1=Activation('relu')(X_1)

    inception=concatenate([X_3,X_5,X_pool,X_1],axis=1)
    return inception

# %%
def inception_block_1b(X):
    X_3=Conv2D(96,(1,1),data_format='channels_first',name='inception_3b_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(128,(3,3),data_format='channels_first',name='inception_3b_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)

    X_5=Conv2D(32,(1,1),data_format='channels_first',name='inception_3b_5x5_conv1')(X)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_5x5_bn1')(X_5)
    X_5=Activation('relu')(X_5)
    X_5=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_5)
    X_5=Conv2D(64,(5,5),data_format='channels_first',name='inception_3b_5x5_conv2')(X_5)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_5x5_bn2')(X_5)
    X_5=Activation('relu')(X_5)

    X_P=AveragePooling2D(pool_size=(3,3),strides=(3,3),data_format='channels_first')(X)
    X_P=Conv2D(64,(1,1),data_format='channels_first',name='inception_3b_pool_conv')(X_P)
    X_P=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_pool_bn')(X_P)
    X_P=Activation('relu')(X_P)
    X_P=ZeroPadding2D(padding=(4,4),data_format='channels_first')(X_P)

    X_1=Conv2D(64,(1,1),data_format='channels_first',name='inception_3b_1x1_conv')(X)
    X_1=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3b_1x1_bn')(X_1)
    X_1=Activation('relu')(X_1)

    inception=concatenate([X_3,X_5,X_P,X_1],axis=1)
    return inception

# %%
def inception_block_1c(X):
    X_3=Conv2D(128,(1,1),data_format='channels_first',name='inception_3c_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3c_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(256,(3,3),strides=(2,2),data_format='channels_first',name='inception_3c_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3c_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)

    X_5=Conv2D(32,(1,1),data_format='channels_first',name='inception_3c_5x5_conv1')(X)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3c_5x5_bn1')(X_5)
    X_5=Activation('relu')(X_5)
    X_5=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_5)
    X_5=Conv2D(64,(5,5),strides=(2,2),data_format='channels_first',name='inception_3c_5x5_conv2')(X_5)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_3c_5x5_bn2')(X_5)
    X_5=Activation('relu')(X_5)

    X_P=MaxPooling2D(pool_size=3,strides=2,data_format='channels_first')(X)
    X_P=ZeroPadding2D(padding=((0,1),(0,1)),data_format='channels_first')(X_P)


    inception=concatenate([X_3,X_5,X_P],axis=1)
    return inception

# %%
def inception_block_2a(X):
    X_3=Conv2D(96,(1,1),data_format='channels_first',name='inception_4a_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(192,(3,3),data_format='channels_first',name='inception_4a_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)

    X_5=Conv2D(32,(1,1),data_format='channels_first',name='inception_4a_5x5_conv1')(X)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_5x5_bn1')(X_5)
    X_5=Activation('relu')(X_5)
    X_5=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_5)
    X_5=Conv2D(64,(5,5),data_format='channels_first',name='inception_4a_5x5_conv2')(X_5)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_5x5_bn2')(X_5)
    X_5=Activation('relu')(X_5)

    X_P=AveragePooling2D(pool_size=(3,3),strides=(3,3),data_format='channels_first')(X)
    X_P=Conv2D(128,(1,1),data_format='channels_first',name='inception_4a_pool_conv')(X_P)
    X_P=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_pool_bn')(X_P)
    X_P=Activation('relu')(X_P)
    X_P=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_P)

    X_1=Conv2D(256,(1,1),data_format='channels_first',name='inception_4a_1x1_conv')(X)
    X_1=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4a_1x1_bn')(X_1)
    X_1=Activation('relu')(X_1)

    inception=concatenate([X_3,X_5,X_P,X_1],axis=1)
    return inception

# %%
def inception_block_2b(X):
    X_3=Conv2D(160,(1,1),data_format='channels_first',name='inception_4e_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4e_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(256,(3,3),strides=(2,2),data_format='channels_first',name='inception_4e_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4e_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)

    X_5=Conv2D(64,(1,1),data_format='channels_first',name='inception_4e_5x5_conv1')(X)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4e_5x5_bn1')(X_5)
    X_5=Activation('relu')(X_5)
    X_5=ZeroPadding2D(padding=(2,2),data_format='channels_first')(X_5)
    X_5=Conv2D(128,(5,5),strides=(2,2),data_format='channels_first',name='inception_4e_5x5_conv2')(X_5)
    X_5=BatchNormalization(axis=1,epsilon=0.00001,name='inception_4e_5x5_bn2')(X_5)
    X_5=Activation('relu')(X_5)

    X_P=MaxPooling2D(pool_size=3,strides=2,data_format='channels_first')(X)
    X_P=ZeroPadding2D(padding=((0,1),(0,1)),data_format='channels_first')(X_P)

    inception=concatenate([X_3,X_5,X_P],axis=1)
    return inception

# %%
def inception_block_3a(X):
    X_3=Conv2D(96,(1,1),data_format='channels_first',name='inception_5a_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5a_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(384,(3,3),data_format='channels_first',name='inception_5a_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5a_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)


    X_P=AveragePooling2D(pool_size=(3,3),strides=(3,3),data_format='channels_first')(X)
    X_P=Conv2D(96,(1,1),data_format='channels_first',name='inception_5a_pool_conv')(X_P)
    X_P=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5a_pool_bn')(X_P)
    X_P=Activation('relu')(X_P)
    X_P=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_P)

    X_1=Conv2D(256,(1,1),data_format='channels_first',name='inception_5a_1x1_conv')(X)
    X_1=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5a_1x1_bn')(X_1)
    X_1=Activation('relu')(X_1)

    inception=concatenate([X_3,X_P,X_1],axis=1)
    return inception

# %%
def inception_block_3b(X):
    X_3=Conv2D(96,(1,1),data_format='channels_first',name='inception_5b_3x3_conv1')(X)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5b_3x3_bn1')(X_3)
    X_3=Activation('relu')(X_3)
    X_3=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_3)
    X_3=Conv2D(384,(3,3),data_format='channels_first',name='inception_5b_3x3_conv2')(X_3)
    X_3=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5b_3x3_bn2')(X_3)
    X_3=Activation('relu')(X_3)


    X_P=MaxPooling2D(pool_size=(3,3),strides=2,data_format='channels_first')(X)
    X_P=Conv2D(96,(1,1),data_format='channels_first',name='inception_5b_pool_conv')(X_P)
    X_P=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5b_pool_bn')(X_P)
    X_P=Activation('relu')(X_P)
    X_P=ZeroPadding2D(padding=(1,1),data_format='channels_first')(X_P)

    X_1=Conv2D(256,(1,1),data_format='channels_first',name='inception_5b_1x1_conv')(X)
    X_1=BatchNormalization(axis=1,epsilon=0.00001,name='inception_5b_1x1_bn')(X_1)
    X_1=Activation('relu')(X_1)

    inception=concatenate([X_3,X_P,X_1],axis=1)
    return inception

# %%
def FinalModel(input_shape):

    X_input=Input(input_shape)

    X=ZeroPadding2D(padding=(3,3))(X_input)
    X=Conv2D(64,(7,7),strides=(2,2),name='conv1')(X)
    X=BatchNormalization(axis=1,name='bn1')(X)
    X=Activation('relu')(X)

    X=ZeroPadding2D((1,1))(X)
    X=MaxPooling2D((3,3),strides=2)(X)

    X=Conv2D(64,(1,1),strides=(1,1),name='conv2')(X)
    X=BatchNormalization(axis=1,epsilon=0.00001,name='bn2')(X)
    X=Activation('relu')(X)

    X=ZeroPadding2D(padding=(1,1))(X)

    X=Conv2D(192,(3,3),strides=(1,1),name='conv3')(X)
    X=BatchNormalization(axis=1,epsilon=0.00001,name='bn3')(X)
    X=Activation('relu')(X)

    X=ZeroPadding2D(padding=(1,1))(X)
    X=MaxPooling2D(pool_size=(3,3),strides=(2,2))(X)

    X=inception_block_1a(X)
    X=inception_block_1b(X)
    X=inception_block_1c(X)

    X=inception_block_2a(X)
    X=inception_block_2b(X)

    X=inception_block_3a(X)
    X=inception_block_3b(X)

    X=AveragePooling2D(pool_size=(3,3),strides=(1,1),data_format='channels_first')(X)
    X=Flatten()(X)
    X=Dense(128,activation='relu',kernel_initializer='glorot_normal',name='dense_layer')(X)
    X=Lambda(lambda x:K.l2_normalize(x,axis=1),name='lambda_1')(X)

    model=Model(inputs=X_input,outputs=X,name='FaceRecognotionModel')
    return model

# %%
model = FinalModel(input_shape = (3, 96, 96))

# %%
model.summary()
# Out:
# Model: "FaceRecognotionModel"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 3, 96, 96)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 3, 102, 102)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 64, 48, 48)           9472      ['zero_padding2d[0][0]']
#
#  bn1 (BatchNormalization)    (None, 64, 48, 48)           256       ['conv1[0][0]']
#
#  activation (Activation)     (None, 64, 48, 48)           0         ['bn1[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 64, 50, 50)           0         ['activation[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2  (None, 64, 24, 24)           0         ['zero_padding2d_1[0][0]']
#  D)
#
#  conv2 (Conv2D)              (None, 64, 24, 24)           4160      ['max_pooling2d[0][0]']
#
#  bn2 (BatchNormalization)    (None, 64, 24, 24)           256       ['conv2[0][0]']
#
#  activation_1 (Activation)   (None, 64, 24, 24)           0         ['bn2[0][0]']
#
#  zero_padding2d_2 (ZeroPadd  (None, 64, 26, 26)           0         ['activation_1[0][0]']
#  ing2D)
#
#  conv3 (Conv2D)              (None, 192, 24, 24)          110784    ['zero_padding2d_2[0][0]']
#
#  bn3 (BatchNormalization)    (None, 192, 24, 24)          768       ['conv3[0][0]']
#
#  activation_2 (Activation)   (None, 192, 24, 24)          0         ['bn3[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 192, 26, 26)          0         ['activation_2[0][0]']
#  ing2D)
#
#  max_pooling2d_1 (MaxPoolin  (None, 192, 12, 12)          0         ['zero_padding2d_3[0][0]']
#  g2D)
#
#  inception_3a_3x3_conv1 (Co  (None, 96, 12, 12)           18528     ['max_pooling2d_1[0][0]']
#  nv2D)
#
#  inception_3a_5x5_conv1 (Co  (None, 16, 12, 12)           3088      ['max_pooling2d_1[0][0]']
#  nv2D)
#
#  inception_3a_3x3_bn1 (Batc  (None, 96, 12, 12)           384       ['inception_3a_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  inception_3a_5x5_bn1 (Batc  (None, 16, 12, 12)           64        ['inception_3a_5x5_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_3 (Activation)   (None, 96, 12, 12)           0         ['inception_3a_3x3_bn1[0][0]']
#
#  activation_5 (Activation)   (None, 16, 12, 12)           0         ['inception_3a_5x5_bn1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 192, 5, 5)            0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  zero_padding2d_4 (ZeroPadd  (None, 96, 14, 14)           0         ['activation_3[0][0]']
#  ing2D)
#
#  zero_padding2d_5 (ZeroPadd  (None, 16, 16, 16)           0         ['activation_5[0][0]']
#  ing2D)
#
#  inception_3a_pool_conv (Co  (None, 32, 5, 5)             6176      ['max_pooling2d_2[0][0]']
#  nv2D)
#
#  inception_3a_3x3_conv2 (Co  (None, 128, 12, 12)          110720    ['zero_padding2d_4[0][0]']
#  nv2D)
#
#  inception_3a_5x5_conv2 (Co  (None, 32, 12, 12)           12832     ['zero_padding2d_5[0][0]']
#  nv2D)
#
#  inception_3a_pool_bn (Batc  (None, 32, 5, 5)             128       ['inception_3a_pool_conv[0][0]
#  hNormalization)                                                    ']
#
#  inception_3a_1x1_conv (Con  (None, 64, 12, 12)           12352     ['max_pooling2d_1[0][0]']
#  v2D)
#
#  inception_3a_3x3_bn2 (Batc  (None, 128, 12, 12)          512       ['inception_3a_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  inception_3a_5x5_bn2 (Batc  (None, 32, 12, 12)           128       ['inception_3a_5x5_conv2[0][0]
#  hNormalization)                                                    ']
#
#  activation_7 (Activation)   (None, 32, 5, 5)             0         ['inception_3a_pool_bn[0][0]']
#
#  inception_3a_1x1_bn (Batch  (None, 64, 12, 12)           256       ['inception_3a_1x1_conv[0][0]'
#  Normalization)                                                     ]
#
#  activation_4 (Activation)   (None, 128, 12, 12)          0         ['inception_3a_3x3_bn2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 12, 12)           0         ['inception_3a_5x5_bn2[0][0]']
#
#  zero_padding2d_6 (ZeroPadd  (None, 32, 12, 12)           0         ['activation_7[0][0]']
#  ing2D)
#
#  activation_8 (Activation)   (None, 64, 12, 12)           0         ['inception_3a_1x1_bn[0][0]']
#
#  concatenate (Concatenate)   (None, 256, 12, 12)          0         ['activation_4[0][0]',
#                                                                      'activation_6[0][0]',
#                                                                      'zero_padding2d_6[0][0]',
#                                                                      'activation_8[0][0]']
#
#  inception_3b_3x3_conv1 (Co  (None, 96, 12, 12)           24672     ['concatenate[0][0]']
#  nv2D)
#
#  inception_3b_5x5_conv1 (Co  (None, 32, 12, 12)           8224      ['concatenate[0][0]']
#  nv2D)
#
#  inception_3b_3x3_bn1 (Batc  (None, 96, 12, 12)           384       ['inception_3b_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  inception_3b_5x5_bn1 (Batc  (None, 32, 12, 12)           128       ['inception_3b_5x5_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_9 (Activation)   (None, 96, 12, 12)           0         ['inception_3b_3x3_bn1[0][0]']
#
#  activation_11 (Activation)  (None, 32, 12, 12)           0         ['inception_3b_5x5_bn1[0][0]']
#
#  average_pooling2d (Average  (None, 256, 4, 4)            0         ['concatenate[0][0]']
#  Pooling2D)
#
#  zero_padding2d_7 (ZeroPadd  (None, 96, 14, 14)           0         ['activation_9[0][0]']
#  ing2D)
#
#  zero_padding2d_8 (ZeroPadd  (None, 32, 16, 16)           0         ['activation_11[0][0]']
#  ing2D)
#
#  inception_3b_pool_conv (Co  (None, 64, 4, 4)             16448     ['average_pooling2d[0][0]']
#  nv2D)
#
#  inception_3b_3x3_conv2 (Co  (None, 128, 12, 12)          110720    ['zero_padding2d_7[0][0]']
#  nv2D)
#
#  inception_3b_5x5_conv2 (Co  (None, 64, 12, 12)           51264     ['zero_padding2d_8[0][0]']
#  nv2D)
#
#  inception_3b_pool_bn (Batc  (None, 64, 4, 4)             256       ['inception_3b_pool_conv[0][0]
#  hNormalization)                                                    ']
#
#  inception_3b_1x1_conv (Con  (None, 64, 12, 12)           16448     ['concatenate[0][0]']
#  v2D)
#
#  inception_3b_3x3_bn2 (Batc  (None, 128, 12, 12)          512       ['inception_3b_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  inception_3b_5x5_bn2 (Batc  (None, 64, 12, 12)           256       ['inception_3b_5x5_conv2[0][0]
#  hNormalization)                                                    ']
#
#  activation_13 (Activation)  (None, 64, 4, 4)             0         ['inception_3b_pool_bn[0][0]']
#
#  inception_3b_1x1_bn (Batch  (None, 64, 12, 12)           256       ['inception_3b_1x1_conv[0][0]'
#  Normalization)                                                     ]
#
#  activation_10 (Activation)  (None, 128, 12, 12)          0         ['inception_3b_3x3_bn2[0][0]']
#
#  activation_12 (Activation)  (None, 64, 12, 12)           0         ['inception_3b_5x5_bn2[0][0]']
#
#  zero_padding2d_9 (ZeroPadd  (None, 64, 12, 12)           0         ['activation_13[0][0]']
#  ing2D)
#
#  activation_14 (Activation)  (None, 64, 12, 12)           0         ['inception_3b_1x1_bn[0][0]']
#
#  concatenate_1 (Concatenate  (None, 320, 12, 12)          0         ['activation_10[0][0]',
#  )                                                                   'activation_12[0][0]',
#                                                                      'zero_padding2d_9[0][0]',
#                                                                      'activation_14[0][0]']
#
#  inception_3c_3x3_conv1 (Co  (None, 128, 12, 12)          41088     ['concatenate_1[0][0]']
#  nv2D)
#
#  inception_3c_5x5_conv1 (Co  (None, 32, 12, 12)           10272     ['concatenate_1[0][0]']
#  nv2D)
#
#  inception_3c_3x3_bn1 (Batc  (None, 128, 12, 12)          512       ['inception_3c_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  inception_3c_5x5_bn1 (Batc  (None, 32, 12, 12)           128       ['inception_3c_5x5_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_15 (Activation)  (None, 128, 12, 12)          0         ['inception_3c_3x3_bn1[0][0]']
#
#  activation_17 (Activation)  (None, 32, 12, 12)           0         ['inception_3c_5x5_bn1[0][0]']
#
#  zero_padding2d_10 (ZeroPad  (None, 128, 14, 14)          0         ['activation_15[0][0]']
#  ding2D)
#
#  zero_padding2d_11 (ZeroPad  (None, 32, 16, 16)           0         ['activation_17[0][0]']
#  ding2D)
#
#  inception_3c_3x3_conv2 (Co  (None, 256, 6, 6)            295168    ['zero_padding2d_10[0][0]']
#  nv2D)
#
#  inception_3c_5x5_conv2 (Co  (None, 64, 6, 6)             51264     ['zero_padding2d_11[0][0]']
#  nv2D)
#
#  inception_3c_3x3_bn2 (Batc  (None, 256, 6, 6)            1024      ['inception_3c_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  inception_3c_5x5_bn2 (Batc  (None, 64, 6, 6)             256       ['inception_3c_5x5_conv2[0][0]
#  hNormalization)                                                    ']
#
#  max_pooling2d_3 (MaxPoolin  (None, 320, 5, 5)            0         ['concatenate_1[0][0]']
#  g2D)
#
#  activation_16 (Activation)  (None, 256, 6, 6)            0         ['inception_3c_3x3_bn2[0][0]']
#
#  activation_18 (Activation)  (None, 64, 6, 6)             0         ['inception_3c_5x5_bn2[0][0]']
#
#  zero_padding2d_12 (ZeroPad  (None, 320, 6, 6)            0         ['max_pooling2d_3[0][0]']
#  ding2D)
#
#  concatenate_2 (Concatenate  (None, 640, 6, 6)            0         ['activation_16[0][0]',
#  )                                                                   'activation_18[0][0]',
#                                                                      'zero_padding2d_12[0][0]']
#
#  inception_4a_3x3_conv1 (Co  (None, 96, 6, 6)             61536     ['concatenate_2[0][0]']
#  nv2D)
#
#  inception_4a_5x5_conv1 (Co  (None, 32, 6, 6)             20512     ['concatenate_2[0][0]']
#  nv2D)
#
#  inception_4a_3x3_bn1 (Batc  (None, 96, 6, 6)             384       ['inception_4a_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  inception_4a_5x5_bn1 (Batc  (None, 32, 6, 6)             128       ['inception_4a_5x5_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_19 (Activation)  (None, 96, 6, 6)             0         ['inception_4a_3x3_bn1[0][0]']
#
#  activation_21 (Activation)  (None, 32, 6, 6)             0         ['inception_4a_5x5_bn1[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 640, 2, 2)            0         ['concatenate_2[0][0]']
#  gePooling2D)
#
#  zero_padding2d_13 (ZeroPad  (None, 96, 8, 8)             0         ['activation_19[0][0]']
#  ding2D)
#
#  zero_padding2d_14 (ZeroPad  (None, 32, 10, 10)           0         ['activation_21[0][0]']
#  ding2D)
#
#  inception_4a_pool_conv (Co  (None, 128, 2, 2)            82048     ['average_pooling2d_1[0][0]']
#  nv2D)
#
#  inception_4a_3x3_conv2 (Co  (None, 192, 6, 6)            166080    ['zero_padding2d_13[0][0]']
#  nv2D)
#
#  inception_4a_5x5_conv2 (Co  (None, 64, 6, 6)             51264     ['zero_padding2d_14[0][0]']
#  nv2D)
#
#  inception_4a_pool_bn (Batc  (None, 128, 2, 2)            512       ['inception_4a_pool_conv[0][0]
#  hNormalization)                                                    ']
#
#  inception_4a_1x1_conv (Con  (None, 256, 6, 6)            164096    ['concatenate_2[0][0]']
#  v2D)
#
#  inception_4a_3x3_bn2 (Batc  (None, 192, 6, 6)            768       ['inception_4a_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  inception_4a_5x5_bn2 (Batc  (None, 64, 6, 6)             256       ['inception_4a_5x5_conv2[0][0]
#  hNormalization)                                                    ']
#
#  activation_23 (Activation)  (None, 128, 2, 2)            0         ['inception_4a_pool_bn[0][0]']
#
#  inception_4a_1x1_bn (Batch  (None, 256, 6, 6)            1024      ['inception_4a_1x1_conv[0][0]'
#  Normalization)                                                     ]
#
#  activation_20 (Activation)  (None, 192, 6, 6)            0         ['inception_4a_3x3_bn2[0][0]']
#
#  activation_22 (Activation)  (None, 64, 6, 6)             0         ['inception_4a_5x5_bn2[0][0]']
#
#  zero_padding2d_15 (ZeroPad  (None, 128, 6, 6)            0         ['activation_23[0][0]']
#  ding2D)
#
#  activation_24 (Activation)  (None, 256, 6, 6)            0         ['inception_4a_1x1_bn[0][0]']
#
#  concatenate_3 (Concatenate  (None, 640, 6, 6)            0         ['activation_20[0][0]',
#  )                                                                   'activation_22[0][0]',
#                                                                      'zero_padding2d_15[0][0]',
#                                                                      'activation_24[0][0]']
#
#  inception_4e_3x3_conv1 (Co  (None, 160, 6, 6)            102560    ['concatenate_3[0][0]']
#  nv2D)
#
#  inception_4e_5x5_conv1 (Co  (None, 64, 6, 6)             41024     ['concatenate_3[0][0]']
#  nv2D)
#
#  inception_4e_3x3_bn1 (Batc  (None, 160, 6, 6)            640       ['inception_4e_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  inception_4e_5x5_bn1 (Batc  (None, 64, 6, 6)             256       ['inception_4e_5x5_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_25 (Activation)  (None, 160, 6, 6)            0         ['inception_4e_3x3_bn1[0][0]']
#
#  activation_27 (Activation)  (None, 64, 6, 6)             0         ['inception_4e_5x5_bn1[0][0]']
#
#  zero_padding2d_16 (ZeroPad  (None, 160, 8, 8)            0         ['activation_25[0][0]']
#  ding2D)
#
#  zero_padding2d_17 (ZeroPad  (None, 64, 10, 10)           0         ['activation_27[0][0]']
#  ding2D)
#
#  inception_4e_3x3_conv2 (Co  (None, 256, 3, 3)            368896    ['zero_padding2d_16[0][0]']
#  nv2D)
#
#  inception_4e_5x5_conv2 (Co  (None, 128, 3, 3)            204928    ['zero_padding2d_17[0][0]']
#  nv2D)
#
#  inception_4e_3x3_bn2 (Batc  (None, 256, 3, 3)            1024      ['inception_4e_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  inception_4e_5x5_bn2 (Batc  (None, 128, 3, 3)            512       ['inception_4e_5x5_conv2[0][0]
#  hNormalization)                                                    ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 640, 2, 2)            0         ['concatenate_3[0][0]']
#  g2D)
#
#  activation_26 (Activation)  (None, 256, 3, 3)            0         ['inception_4e_3x3_bn2[0][0]']
#
#  activation_28 (Activation)  (None, 128, 3, 3)            0         ['inception_4e_5x5_bn2[0][0]']
#
#  zero_padding2d_18 (ZeroPad  (None, 640, 3, 3)            0         ['max_pooling2d_4[0][0]']
#  ding2D)
#
#  concatenate_4 (Concatenate  (None, 1024, 3, 3)           0         ['activation_26[0][0]',
#  )                                                                   'activation_28[0][0]',
#                                                                      'zero_padding2d_18[0][0]']
#
#  inception_5a_3x3_conv1 (Co  (None, 96, 3, 3)             98400     ['concatenate_4[0][0]']
#  nv2D)
#
#  inception_5a_3x3_bn1 (Batc  (None, 96, 3, 3)             384       ['inception_5a_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_29 (Activation)  (None, 96, 3, 3)             0         ['inception_5a_3x3_bn1[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1024, 1, 1)           0         ['concatenate_4[0][0]']
#  gePooling2D)
#
#  zero_padding2d_19 (ZeroPad  (None, 96, 5, 5)             0         ['activation_29[0][0]']
#  ding2D)
#
#  inception_5a_pool_conv (Co  (None, 96, 1, 1)             98400     ['average_pooling2d_2[0][0]']
#  nv2D)
#
#  inception_5a_3x3_conv2 (Co  (None, 384, 3, 3)            332160    ['zero_padding2d_19[0][0]']
#  nv2D)
#
#  inception_5a_pool_bn (Batc  (None, 96, 1, 1)             384       ['inception_5a_pool_conv[0][0]
#  hNormalization)                                                    ']
#
#  inception_5a_1x1_conv (Con  (None, 256, 3, 3)            262400    ['concatenate_4[0][0]']
#  v2D)
#
#  inception_5a_3x3_bn2 (Batc  (None, 384, 3, 3)            1536      ['inception_5a_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  activation_31 (Activation)  (None, 96, 1, 1)             0         ['inception_5a_pool_bn[0][0]']
#
#  inception_5a_1x1_bn (Batch  (None, 256, 3, 3)            1024      ['inception_5a_1x1_conv[0][0]'
#  Normalization)                                                     ]
#
#  activation_30 (Activation)  (None, 384, 3, 3)            0         ['inception_5a_3x3_bn2[0][0]']
#
#  zero_padding2d_20 (ZeroPad  (None, 96, 3, 3)             0         ['activation_31[0][0]']
#  ding2D)
#
#  activation_32 (Activation)  (None, 256, 3, 3)            0         ['inception_5a_1x1_bn[0][0]']
#
#  concatenate_5 (Concatenate  (None, 736, 3, 3)            0         ['activation_30[0][0]',
#  )                                                                   'zero_padding2d_20[0][0]',
#                                                                      'activation_32[0][0]']
#
#  inception_5b_3x3_conv1 (Co  (None, 96, 3, 3)             70752     ['concatenate_5[0][0]']
#  nv2D)
#
#  inception_5b_3x3_bn1 (Batc  (None, 96, 3, 3)             384       ['inception_5b_3x3_conv1[0][0]
#  hNormalization)                                                    ']
#
#  activation_33 (Activation)  (None, 96, 3, 3)             0         ['inception_5b_3x3_bn1[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 736, 1, 1)            0         ['concatenate_5[0][0]']
#  g2D)
#
#  zero_padding2d_21 (ZeroPad  (None, 96, 5, 5)             0         ['activation_33[0][0]']
#  ding2D)
#
#  inception_5b_pool_conv (Co  (None, 96, 1, 1)             70752     ['max_pooling2d_5[0][0]']
#  nv2D)
#
#  inception_5b_3x3_conv2 (Co  (None, 384, 3, 3)            332160    ['zero_padding2d_21[0][0]']
#  nv2D)
#
#  inception_5b_pool_bn (Batc  (None, 96, 1, 1)             384       ['inception_5b_pool_conv[0][0]
#  hNormalization)                                                    ']
#
#  inception_5b_1x1_conv (Con  (None, 256, 3, 3)            188672    ['concatenate_5[0][0]']
#  v2D)
#
#  inception_5b_3x3_bn2 (Batc  (None, 384, 3, 3)            1536      ['inception_5b_3x3_conv2[0][0]
#  hNormalization)                                                    ']
#
#  activation_35 (Activation)  (None, 96, 1, 1)             0         ['inception_5b_pool_bn[0][0]']
#
#  inception_5b_1x1_bn (Batch  (None, 256, 3, 3)            1024      ['inception_5b_1x1_conv[0][0]'
#  Normalization)                                                     ]
#
#  activation_34 (Activation)  (None, 384, 3, 3)            0         ['inception_5b_3x3_bn2[0][0]']
#
#  zero_padding2d_22 (ZeroPad  (None, 96, 3, 3)             0         ['activation_35[0][0]']
#  ding2D)
#
#  activation_36 (Activation)  (None, 256, 3, 3)            0         ['inception_5b_1x1_bn[0][0]']
#
#  concatenate_6 (Concatenate  (None, 736, 3, 3)            0         ['activation_34[0][0]',
#  )                                                                   'zero_padding2d_22[0][0]',
#                                                                      'activation_36[0][0]']
#
#  average_pooling2d_3 (Avera  (None, 736, 1, 1)            0         ['concatenate_6[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 736)                  0         ['average_pooling2d_3[0][0]']
#
#  dense_layer (Dense)         (None, 128)                  94336     ['flatten[0][0]']
#
#  lambda_1 (Lambda)           (None, 128)                  0         ['dense_layer[0][0]']
#
# ==================================================================================================
# Total params: 3743280 (14.28 MB)
# Trainable params: 3733968 (14.24 MB)
# Non-trainable params: 9312 (36.38 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
def triplet_loss(y_true,y_pred):
    #print(y_pred)
    anchor=y_pred[:,0:128]
    pos=y_pred[:,128:256]
    neg=y_pred[:,256:384]

    positive_distance = K.sum(K.abs(anchor-pos), axis=1)
    negative_distance = K.sum(K.abs(anchor-neg), axis=1)
    probs=K.softmax([positive_distance,negative_distance],axis=0)
    #loss = positive_distance - negative_distance+alpha
    loss=K.mean(K.abs(probs[0])+K.abs(1.0-probs[1]))
    return loss

# %%
def preprocess_img(path_img, path_har = "/content/haarcascade_frontalface_default.xml"):
    image = cv2.imread(path_img)
    img_gry = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier(path_har)
    faces = face_cascade.detectMultiScale(img_gry, 1.1, 6)
    if len(faces) != 1:
      return -1

    x, y, w, h = faces.squeeze()
    crop = image[y : y + h, x : x + w]
    image = cv2.resize(crop, (96, 96))
    image = np.transpose(image, (2, 0, 1))
    image = image.astype("float32") / 255.0
    return image

# %%
def data_gen(batch_size=32):
    while True:
        i=0
        pos_dirs =[]
        anchor_dirs =[]
        neg_dirs =[]


        while(i<batch_size):
            r=random.choice(os.listdir(path))
            p=path+'/'+ r
            id=os.listdir(p)
            ra=random.sample(id,2)
            pos_dir=p+'/'+ra[0]
            neg_dir=p+'/'+ra[1]
            pos=pos_dir+'/'+random.choice(os.listdir(pos_dir))
            anc=pos_dir+'/'+random.choice([x for x in os.listdir(pos_dir) if 'script' in x])
            neg=neg_dir+'/'+random.choice(os.listdir(neg_dir))
            pos_img= preprocess_img(pos, face_path)
                    #print(pos+anc+neg)
            if pos_img is -1:
                continue
            neg_img= preprocess_img(neg,face_path)
            if neg_img is -1:
                continue
            anc_img= preprocess_img(anc,face_path)
            if anc_img is -1:
                continue
            pos_dirs.append(list(pos_img))
                #print('positive{0}'.format(i))
            neg_dirs.append(list(neg_img))
                #print('negative{0}'.format(i))
            anchor_dirs.append(list(anc_img))
                #print('anchor{0}'.format(i))
            i=i+1
        #return anchor,positive,negative
        yield ([np.array(anchor_dirs),np.array(pos_dirs),np.array(neg_dirs)],np.zeros((batch_size,1)).astype("float32"))

# %%
anchor_model_t = Input((3,96,96))
neg_model_t = Input((3,96,96))
pos_model_t = Input((3,96,96))
triplet_model_out=Concatenate()([model(anchor_model_t),model(pos_model_t),model(neg_model_t)])
triplet_model=Model([anchor_model_t,pos_model_t,neg_model_t],triplet_model_out)

# %%
triplet_model.compile(optimizer='adam',loss=triplet_loss)

# %%
triplet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 3, 96, 96)]          0         []
#
#  input_4 (InputLayer)        [(None, 3, 96, 96)]          0         []
#
#  input_3 (InputLayer)        [(None, 3, 96, 96)]          0         []
#
#  FaceRecognotionModel (Func  (None, 128)                  3743280   ['input_2[0][0]',
#  tional)                                                             'input_4[0][0]',
#                                                                      'input_3[0][0]']
#
#  concatenate_7 (Concatenate  (None, 384)                  0         ['FaceRecognotionModel[0][0]',
#  )                                                                   'FaceRecognotionModel[1][0]',
#                                                                      'FaceRecognotionModel[2][0]']
#
# ==================================================================================================
# Total params: 3743280 (14.28 MB)
# Trainable params: 3733968 (14.24 MB)
# Non-trainable params: 9312 (36.38 KB)
# __________________________________________________________________________________________________

# %%
triplet_model.fit(data_gen(), steps_per_epoch = 100, epochs = 5)

# %%
def image_resizing(image, face_path):

    gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    classifier=cv2.CascadeClassifier(face_path)
    faces=classifier.detectMultiScale(gray,1.1,6)

    if len(faces)!=1:
        print('More than one Image in the selfie')
        sys.exit(0)
    x,y,w,h=faces.squeeze()
    crop=image[y:y+h,x:x+w]
    image=cv2.resize(crop,(96,96))

    return image

# %%
def encode_img(img1,triplet_model):
    #img1=cv2.imread(path,1)
    img=img1[...,::-1]
    img=np.around(np.transpose(img,(2,0,1))/255,decimals=12)
    x_train=np.array([img])
    emb=triplet_model.layers[3].predict_on_batch(x_train)
    return emb

# %%
threshold=0.65
interval=0.3
def confidence_value(ref_encode,img_encode,thres=threshold):
    #diff=np.max(img_encode-ref_encode)
    dist=np.linalg.norm((img_encode-ref_encode))
    #confidence=(1-K.eval(tf.minimum(dist,1)))
    confidence=(threshold-max([dist,interval]))/(threshold-interval)
    return dist,confidence
