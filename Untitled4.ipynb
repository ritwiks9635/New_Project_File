# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwiks9635/New_Project_File/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from IPython.display import clear_output
from matplotlib.pyplot import imshow
import pandas as pd
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.activations import *
from tensorflow.keras.metrics import *
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import backend as k
import datetime

# %%
train_df = pd.read_csv("/content/UCF101TrainTestSplits-RecognitionTask/ucfTrainTestlist/trainlist01.txt", sep = " ", header=None, names = ["path", "class"])
train_df.head()
# Out:
#                                           path  class
# 0  ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c01.avi      1
# 1  ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c02.avi      1
# 2  ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c03.avi      1
# 3  ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c04.avi      1
# 4  ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c05.avi      1

# %%
train_df.shape
# Out:
# (9537, 2)

# %%
content = []
i = 0
n = 50
while len(content) < 10 and i < 102:
  if len(train_df[train_df["class"] == i]) >= n:
    df_temp = train_df[train_df["class"] == i].iloc[:n]
    path = df_temp["path"]
    content.append(path)
  i += 1

content = np.array(content)

# %%
content.shape
# Out:
# (10, 50)

# %%
df_temp
# Out:
#                                     path  class
# 873  BenchPress/v_BenchPress_g08_c01.avi     10
# 874  BenchPress/v_BenchPress_g08_c02.avi     10
# 875  BenchPress/v_BenchPress_g08_c03.avi     10
# 876  BenchPress/v_BenchPress_g08_c04.avi     10
# 877  BenchPress/v_BenchPress_g08_c05.avi     10
# 878  BenchPress/v_BenchPress_g08_c06.avi     10
# 879  BenchPress/v_BenchPress_g08_c07.avi     10
# 880  BenchPress/v_BenchPress_g09_c01.avi     10
# 881  BenchPress/v_BenchPress_g09_c02.avi     10
# 882  BenchPress/v_BenchPress_g09_c03.avi     10
# 883  BenchPress/v_BenchPress_g09_c04.avi     10
# 884  BenchPress/v_BenchPress_g09_c05.avi     10
# 885  BenchPress/v_BenchPress_g09_c06.avi     10
# 886  BenchPress/v_BenchPress_g09_c07.avi     10
# 887  BenchPress/v_BenchPress_g10_c01.avi     10
# 888  BenchPress/v_BenchPress_g10_c02.avi     10
# 889  BenchPress/v_BenchPress_g10_c03.avi     10
# 890  BenchPress/v_BenchPress_g10_c04.avi     10
# 891  BenchPress/v_BenchPress_g11_c01.avi     10
# 892  BenchPress/v_BenchPress_g11_c02.avi     10
# 893  BenchPress/v_BenchPress_g11_c03.avi     10
# 894  BenchPress/v_BenchPress_g11_c04.avi     10
# 895  BenchPress/v_BenchPress_g11_c05.avi     10
# 896  BenchPress/v_BenchPress_g12_c01.avi     10
# 897  BenchPress/v_BenchPress_g12_c02.avi     10
# 898  BenchPress/v_BenchPress_g12_c03.avi     10
# 899  BenchPress/v_BenchPress_g12_c04.avi     10
# 900  BenchPress/v_BenchPress_g12_c05.avi     10
# 901  BenchPress/v_BenchPress_g12_c06.avi     10
# 902  BenchPress/v_BenchPress_g12_c07.avi     10
# 903  BenchPress/v_BenchPress_g13_c01.avi     10
# 904  BenchPress/v_BenchPress_g13_c02.avi     10
# 905  BenchPress/v_BenchPress_g13_c03.avi     10
# 906  BenchPress/v_BenchPress_g13_c04.avi     10
# 907  BenchPress/v_BenchPress_g13_c05.avi     10
# 908  BenchPress/v_BenchPress_g13_c06.avi     10
# 909  BenchPress/v_BenchPress_g13_c07.avi     10
# 910  BenchPress/v_BenchPress_g14_c01.avi     10
# 911  BenchPress/v_BenchPress_g14_c02.avi     10
# 912  BenchPress/v_BenchPress_g14_c03.avi     10
# 913  BenchPress/v_BenchPress_g14_c04.avi     10
# 914  BenchPress/v_BenchPress_g14_c05.avi     10
# 915  BenchPress/v_BenchPress_g14_c06.avi     10
# 916  BenchPress/v_BenchPress_g14_c07.avi     10
# 917  BenchPress/v_BenchPress_g15_c01.avi     10
# 918  BenchPress/v_BenchPress_g15_c02.avi     10
# 919  BenchPress/v_BenchPress_g15_c03.avi     10
# 920  BenchPress/v_BenchPress_g15_c04.avi     10
# 921  BenchPress/v_BenchPress_g15_c05.avi     10
# 922  BenchPress/v_BenchPress_g15_c06.avi     10

# %%
content = content.reshape(500,)
y = np.array([i//50 for i in range(0,500)])

# %%
y.shape
# Out:
# (500,)

# %%
content.shape
# Out:
# (500,)

# %%
def read_frames(root_folder, arr, each_nth = 10):
  videos = []
  for j in range(len(arr)):
    clear_output()
    print(np.round(100*j/len(arr),3))

    vcap = cv2.VideoCapture(root_folder + arr[j])
    success = True
    frames = []
    cnt = 0
    while success:
      try:
        success, image = vcap.read()
        cnt+=1
        if cnt%each_nth == 0:
          image = resize(image,(128,192))
          frames.append(image)
      except Exception as e:
        print(e)
    videos.append(frames)
  return videos

# %%
def select_frames(frames_arr, n=10):
  videos = []
  for i in range(len(frames_arr)):
    frames = []
    for t in np.linspace(0, len(frames_arr[i])-1, num=n):
      frames.append(frames_arr[i][int(t)])
    videos.append(frames)
  videos = np.array(videos)
  print(videos.shape)
  return videos

# %%
X_frames = read_frames("/content/UCF101/UCF-101/",content)
X_frames = select_frames(X_frames, 10)
# Out:
# 99.8
# (500, 10, 128, 192, 3)

# %%
X_train, x_test, y_train, y_test = train_test_split(X_frames, y, shuffle = True, test_size=0.2, random_state = 42)

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
y_train.shape
# Out:
# (400, 10)

# %%
plt.figure(figsize=(32,8))
random_video = np.random.randint(0, len(X_frames))
for i, image  in enumerate(X_frames[random_video]):
  plt.subplot(2,5,i+1)
  plt.imshow(image)

# %%
def list_to_stack(xs):
  xs = tf.stack(xs, axis = 1)
  s = tf.shape(xs)
  return xs

# %%
ish=(10, 128, 192, 3)

xs=[]


inp = Input(ish)

for slice_indx in range(0,10,1):
  x=Lambda(lambda x: x[:, slice_indx])(inp)
  x=BatchNormalization(momentum=0.8)(x)
  x=Conv2D(filters=20, kernel_size=3, padding='same', activation='relu')(x)
  x=BatchNormalization(momentum=0.8)(x)
  x=MaxPooling2D(pool_size=2)(x)

  x=Conv2D(filters=30, kernel_size=3, padding='same', activation='relu')(x)
  x=BatchNormalization(momentum=0.8)(x)
  x=MaxPooling2D(pool_size=2)(x)
  x=Conv2D(filters=30, kernel_size=3, padding='same', activation='relu')(x)

  xs.append(x)


t=Lambda(list_to_stack)(xs)
t=Conv3D(50,3,padding='same')(t)
t=BatchNormalization(momentum=0.8)(t)
target_shape=(10,32*48*50)
t=Reshape(target_shape)(t)
t=GRU(25, return_sequences=True)(t)
t=GRU(50, return_sequences=False,dropout=0.5)(t)

t=Dense(100,'relu')(t)
out=Dense(10, activation='softmax')(t)

model = Model(inputs=inp, outputs=out)
opt = tf.keras.optimizers.SGD(lr=0.0087)
model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
history = model.fit(X_train, y_train, epochs = 5, batch_size = 10, validation_data = (x_test, y_test), shuffle = True)
# Out:
# Epoch 1/5
# 40/40 [==============================] - 30s 161ms/step - loss: 2.0479 - accuracy: 0.3600 - val_loss: 1.9020 - val_accuracy: 0.4300
# Epoch 2/5
# 40/40 [==============================] - 4s 101ms/step - loss: 1.6772 - accuracy: 0.6275 - val_loss: 1.5907 - val_accuracy: 0.6500
# Epoch 3/5
# 40/40 [==============================] - 4s 91ms/step - loss: 1.3662 - accuracy: 0.7925 - val_loss: 1.3388 - val_accuracy: 0.7600
# Epoch 4/5
# 40/40 [==============================] - 4s 98ms/step - loss: 1.1096 - accuracy: 0.8825 - val_loss: 1.0581 - val_accuracy: 0.8800
# Epoch 5/5
# 40/40 [==============================] - 4s 91ms/step - loss: 0.9025 - accuracy: 0.9275 - val_loss: 0.8752 - val_accuracy: 0.9200

# %%
classes = []
for i in range(len(content)):
    class_name = content[i].split('/')[0]
    if class_name not in classes:
        classes.append(class_name)

num_classes = [i for i in range(10)]
class_map = dict(zip(num_classes,classes))

# %%
random_videos = np.random.randint(0,len(x_test),size=(10))
predicted  = model.predict(x_test[random_videos],batch_size = 10)
predicted  = np.argmax(predicted,axis=1)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
fig = plt.figure(figsize=(30,10))

for i,rand_indx in enumerate(random_videos):
    ax = plt.subplot(2,5,i+1)
    video = x_test[rand_indx]
    frame = video[np.random.randint(0,10)]
    ax.set_title(class_map[predicted[i]])
    imshow(frame)
